# %%
import pandas as pd
import numpy as np

# %%
df_etf_1 = pd.read_csv("data/etf_1.csv")

# %%
print(df_etf_1.head())
# Out:
#   Ticker                        Fund Name ESG Rating Quality Score  \
# 0    SPY           SPDR S&P 500 ETF Trust          A     6.68 / 10
# 1    IVV         iShares Core S&P 500 ETF          A     6.68 / 10
# 2    VOO          Vanguard 500 Index Fund          A     6.68 / 10
# 3    VTI  Vanguard Total Stock Market ETF          A     6.52 / 10
# 4    QQQ                Invesco QQQ Trust          A     6.71 / 10
#
#   Score Peer Rank Score Global Rank Carbon Intensity  \
# 0           58.71             47.34           122.31
# 1           58.67             47.01           122.41
# 2           58.75             47.99           122.47
# 3           52.51             24.74           122.61
# 4           59.94             55.16            47.01
#
#   Sustainable Impact Exposure SRI Screening Criteria Exposure
# 0                          --                           9.75%
# 1                          --                           9.67%
# ...

# %%
df_etf_1 = df_etf_1[['Ticker', 'Fund Name', 'ESG Rating', 'Quality Score', 'Score Peer Rank', 'Score Global Rank', 'Carbon Intensity', 'Sustainable Impact Exposure', 'SRI Screening Criteria Exposure']]
df_etf_1
# Out:
#    Ticker                                        Fund Name ESG Rating  \
# 0     SPY                           SPDR S&P 500 ETF Trust          A
# 1     IVV                         iShares Core S&P 500 ETF          A
# 2     VOO                          Vanguard 500 Index Fund          A
# 3     VTI                  Vanguard Total Stock Market ETF          A
# 4     QQQ                                Invesco QQQ Trust          A
# ..    ...                                              ...        ...
# 95    BIV              Vanguard Intermediate-Term Bond ETF          A
# 96   VGIT    Vanguard Intermediate-Term Treasury Index ETF          A
# 97    HYG  iShares iBoxx USD High Yield Corporate Bond ETF        BBB
# 98   SCHA                        Schwab U.S. Small-Cap ETF        BBB
# 99    VBK                    Vanguard Small-Cap Growth ETF        BBB
#
#    Quality Score Score Peer Rank Score Global Rank Carbon Intensity  \
# ...

# %%
df_etf_1.columns = df_etf_1.columns.str.replace(" ","_").str.lower()
df_etf_1.head()
# Out:
#   ticker                        fund_name esg_rating quality_score  \
# 0    SPY           SPDR S&P 500 ETF Trust          A     6.68 / 10
# 1    IVV         iShares Core S&P 500 ETF          A     6.68 / 10
# 2    VOO          Vanguard 500 Index Fund          A     6.68 / 10
# 3    VTI  Vanguard Total Stock Market ETF          A     6.52 / 10
# 4    QQQ                Invesco QQQ Trust          A     6.71 / 10
#
#   score_peer_rank score_global_rank carbon_intensity  \
# 0           58.71             47.34           122.31
# 1           58.67             47.01           122.41
# 2           58.75             47.99           122.47
# 3           52.51             24.74           122.61
# 4           59.94             55.16            47.01
#
#   sustainable_impact_exposure sri_screening_criteria_exposure
# 0                          --                           9.75%
# 1                          --                           9.67%
# ...

# %%
df_etf_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 9 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   ticker                           100 non-null    object
#  1   fund_name                        100 non-null    object
#  2   esg_rating                       93 non-null     object
#  3   quality_score                    100 non-null    object
#  4   score_peer_rank                  100 non-null    object
#  5   score_global_rank                100 non-null    object
#  6   carbon_intensity                 100 non-null    object
#  7   sustainable_impact_exposure      100 non-null    object
#  8   sri_screening_criteria_exposure  100 non-null    object
# dtypes: object(9)
# memory usage: 7.2+ KB

# %%
df_etf_2 = pd.read_csv("data/etf_2.csv")

# %%
df_etf_2 = df_etf_2[['Ticker', 'Fund Name', 'ESG Rating', 'Quality Score', 'Score Peer Rank', 'Score Global Rank', 'Carbon Intensity', 'Sustainable Impact Exposure', 'SRI Screening Criteria Exposure']]
df_etf_2.columns = df_etf_2.columns.str.replace(" ","_").str.lower()
df_etf_2.head()
# Out:
#   ticker                                          fund_name esg_rating  \
# 0   IUSV                    iShares Core S&P U.S. Value ETF          A
# 1    MGK                       Vanguard Mega Cap Growth ETF          A
# 2   QQQM                             Invesco NASDAQ 100 ETF          A
# 3   VTIP  Vanguard Short-Term Inflation-Protected Securi...          A
# 4   COWZ                       Pacer U.S. Cash Cows 100 ETF          A
#
#   quality_score score_peer_rank score_global_rank carbon_intensity  \
# 0     6.48 / 10           51.15             21.39           180.67
# 1     6.81 / 10           63.75             67.14            35.40
# 2     6.71 / 10           59.96             55.47            47.00
# 3     5.72 / 10           34.34             64.21               --
# 4     6.54 / 10           53.34             27.30           233.72
#
#   sustainable_impact_exposure sri_screening_criteria_exposure
# 0                          --                          14.99%
# ...

# %%
df_etf_3 = pd.read_csv("data/etf_3.csv")
df_etf_3 = df_etf_3[['Ticker', 'Fund Name', 'ESG Rating', 'Quality Score', 'Score Peer Rank', 'Score Global Rank', 'Carbon Intensity', 'Sustainable Impact Exposure', 'SRI Screening Criteria Exposure']]
df_etf_3.columns = df_etf_3.columns.str.replace(" ","_").str.lower()
df_etf_3.head()
# Out:
#   ticker                                          fund_name esg_rating  \
# 0    VPL                          Vanguard FTSE Pacific ETF          A
# 1    XLB                  Materials Select Sector SPDR Fund          A
# 2   VTWO                          Vanguard Russell 2000 ETF        BBB
# 3   VYMI     Vanguard International High Dividend Yield ETF          A
# 4   SPIB  SPDR Portfolio Intermediate Term Corporate Bon...          A
#
#   quality_score score_peer_rank score_global_rank carbon_intensity  \
# 0     6.85 / 10           65.18             68.84           128.81
# 1     6.78 / 10           62.73             71.31           620.83
# 2     5.20 / 10           26.71             11.49           143.46
# 3     6.98 / 10           70.65             20.74           221.85
# 4     6.66 / 10           57.41             70.57           227.15
#
#   sustainable_impact_exposure sri_screening_criteria_exposure
# 0                          --                           8.17%
# ...

# %%
df_etf_4 = pd.read_csv("data/etf_4.csv")
df_etf_4 = df_etf_4[['Ticker', 'Fund Name', 'ESG Rating', 'Quality Score', 'Score Peer Rank', 'Score Global Rank', 'Carbon Intensity', 'Sustainable Impact Exposure', 'SRI Screening Criteria Exposure']]
df_etf_4.columns = df_etf_4.columns.str.replace(" ","_").str.lower()
df_etf_4.head()
# Out:
#   ticker                              fund_name esg_rating quality_score  \
# 0   BOND                  PIMCO Active Bond ETF        NaN            --
# 1   VSGX   Vanguard ESG International Stock ETF          A     7.11 / 10
# 2   HEFA  iShares Currency Hedged MSCI EAFE ETF         AA     7.71 / 10
# 3    KRE          SPDR S&P Regional Banking ETF        BBB     4.61 / 10
# 4    GNR  SPDR S&P Global Natural Resources ETF          A     6.92 / 10
#
#   score_peer_rank score_global_rank carbon_intensity  \
# 0              --                --               --
# 1           75.46             18.95            99.05
# 2           92.51             75.91           101.28
# 3           16.86             13.31             5.39
# 4           68.06             70.21           353.58
#
#   sustainable_impact_exposure sri_screening_criteria_exposure
# 0                          --                              --
# 1                          --                           0.47%
# ...

# %%
df_etf_5 = pd.read_csv("data/etf_5.csv")
df_etf_5 = df_etf_5[['Ticker', 'Fund Name', 'ESG Rating', 'Quality Score', 'Score Peer Rank', 'Score Global Rank', 'Carbon Intensity', 'Sustainable Impact Exposure', 'SRI Screening Criteria Exposure']]
df_etf_5.columns = df_etf_5.columns.str.replace(" ","_").str.lower()
df_etf_5.head()
# Out:
#   ticker                                          fund_name esg_rating  \
# 0   IBDQ         iShares iBonds Dec 2025 Term Corporate ETF          A
# 1    DBC           Invesco DB Commodity Index Tracking Fund        NaN
# 2    RWL                        Invesco S&P 500 Revenue ETF          A
# 3   IGLB  iShares 10+ Year Investment Grade Corporate Bo...          A
# 4   QQEW   First Trust Nasdaq-100 Equal Weighted Index Fund          A
#
#   quality_score score_peer_rank score_global_rank carbon_intensity  \
# 0     6.77 / 10           62.25             81.56           187.22
# 1            --              --                --               --
# 2     6.43 / 10           49.73             18.55           136.92
# 3     6.40 / 10           48.87             39.36           460.46
# 4     6.67 / 10           57.94             42.37           119.26
#
#   sustainable_impact_exposure sri_screening_criteria_exposure
# 0                          --                           8.25%
# ...

# %%
df_etf_6 = pd.read_csv("data/etf_6.csv")
df_etf_6 = df_etf_6[['Ticker', 'Fund Name', 'ESG Rating', 'Quality Score', 'Score Peer Rank', 'Score Global Rank', 'Carbon Intensity', 'Sustainable Impact Exposure', 'SRI Screening Criteria Exposure']]
df_etf_6.columns = df_etf_6.columns.str.replace(" ","_").str.lower()
df_etf_6.head()
# Out:
#   ticker                                 fund_name esg_rating quality_score  \
# 0    ILF              iShares Latin America 40 ETF        BBB     5.24 / 10
# 1   FNCL        Fidelity MSCI Financials Index ETF        BBB     5.46 / 10
# 2   HEDJ      WisdomTree Europe Hedged Equity Fund         AA     7.57 / 10
# 3   ICVT              iShares Convertible Bond ETF        BBB     5.62 / 10
# 4   ESML  iShares ESG Aware MSCI USA Small-Cap ETF          A     6.43 / 10
#
#   score_peer_rank score_global_rank carbon_intensity  \
# 0           27.21             60.55           255.08
# 1           29.98             24.15            31.30
# 2           89.44             20.58           125.83
# 3           32.32             23.33           223.90
# 4           49.53             87.20           100.80
#
#   sustainable_impact_exposure sri_screening_criteria_exposure
# 0                          --                           5.04%
# 1                          --                          10.09%
# ...

# %%
df_etf_7 = pd.read_csv("data/etf_7.csv")
df_etf_7 = df_etf_7[['Ticker', 'Fund Name', 'ESG Rating', 'Quality Score', 'Score Peer Rank', 'Score Global Rank', 'Carbon Intensity', 'Sustainable Impact Exposure', 'SRI Screening Criteria Exposure']]
df_etf_7.columns = df_etf_7.columns.str.replace(" ","_").str.lower()
df_etf_7.head()
# Out:
#   ticker                                          fund_name esg_rating  \
# 0    PKW                      Invesco BuyBack Achievers ETF          A
# 1    GEM  Goldman Sachs ActiveBeta Emerging Markets Equi...        BBB
# 2    KSA                      iShares MSCI Saudi Arabia ETF         BB
# 3    GTO                      Invesco Total Return Bond ETF        NaN
# 4   GSUS           Goldman Sachs MarketBeta U.S. Equity ETF          A
#
#   quality_score score_peer_rank score_global_rank carbon_intensity  \
# 0     6.43 / 10           49.66             18.27           114.84
# 1     5.37 / 10           28.80             12.73           292.57
# 2     3.67 / 10            4.67              0.22           794.10
# 3            --              --                --               --
# 4     6.66 / 10           57.60             40.68           116.17
#
#   sustainable_impact_exposure sri_screening_criteria_exposure
# 0                          --                           2.38%
# ...

# %%
df_etf_8 = pd.read_csv("data/etf_8.csv")
df_etf_8 = df_etf_8[['Ticker', 'Fund Name', 'ESG Rating', 'Quality Score', 'Score Peer Rank', 'Score Global Rank', 'Carbon Intensity', 'Sustainable Impact Exposure', 'SRI Screening Criteria Exposure']]
df_etf_8.columns = df_etf_8.columns.str.replace(" ","_").str.lower()
df_etf_8.head()
# Out:
#   ticker                            fund_name esg_rating quality_score  \
# 0   ALTL  Pacer Lunt Large Cap Alternator ETF          A     6.76 / 10
# 1   USXF    iShares ESG Advanced MSCI USA ETF         AA     7.62 / 10
# 2   FTLS    First Trust Long/Short Equity ETF          A     6.40 / 10
# 3   DFAR       Dimensional US Real Estate ETF          A     6.07 / 10
# 4   DWAS    Invesco DWA SmallCap Momentum ETF        BBB     5.02 / 10
#
#   score_peer_rank score_global_rank carbon_intensity  \
# 0           61.98             62.38           533.32
# 1           90.57             98.51            62.28
# 2           48.72             47.66            90.95
# 3           40.62             62.92            87.94
# 4           24.55              5.95           155.15
#
#   sustainable_impact_exposure sri_screening_criteria_exposure
# 0                          --                          21.35%
# 1                          --                           0.18%
# ...

# %%
df_etf_9 = pd.read_csv("data/etf_9.csv")
df_etf_9 = df_etf_9[['Ticker', 'Fund Name', 'ESG Rating', 'Quality Score', 'Score Peer Rank', 'Score Global Rank', 'Carbon Intensity', 'Sustainable Impact Exposure', 'SRI Screening Criteria Exposure']]
df_etf_9.columns = df_etf_9.columns.str.replace(" ","_").str.lower()
df_etf_9.head()
# Out:
#   ticker                                   fund_name esg_rating quality_score  \
# 0    UYG                  ProShares Ultra Financials          A     5.98 / 10
# 1   IBMM  iShares iBonds Dec 2024 Term Muni Bond ETF        NaN            --
# 2   KRBN      KraneShares Global Carbon Strategy ETF        NaN            --
# 3    AGZ                     iShares Agency Bond ETF        BBB     4.54 / 10
# 4   DRSK                      Aptus Defined Risk ETF          A     6.65 / 10
#
#   score_peer_rank score_global_rank carbon_intensity  \
# 0           38.88             36.84            39.57
# 1              --                --               --
# 2              --                --               --
# 3           14.00              3.38           511.14
# 4           56.92             83.96           226.62
#
#   sustainable_impact_exposure sri_screening_criteria_exposure
# 0                          --                           9.72%
# ...

# %%
df_etf_10 = pd.read_csv("data/etf_10.csv")
df_etf_10 = df_etf_10[['Ticker', 'Fund Name', 'ESG Rating', 'Quality Score', 'Score Peer Rank', 'Score Global Rank', 'Carbon Intensity', 'Sustainable Impact Exposure', 'SRI Screening Criteria Exposure']]
df_etf_10.columns = df_etf_10.columns.str.replace(" ","_").str.lower()
df_etf_10.head()
# Out:
#   ticker                                          fund_name esg_rating  \
# 0   NUSI      Nationwide Nasdaq-100 Risk-Managed Income ETF          A
# 1   CMBS                                   iShares CMBS ETF        NaN
# 2   AIRR  First Trust RBA American Industrial Renaissanc...          A
# 3   GSID  Goldman Sachs MarketBeta International Equity ETF         AA
# 4   BKMC              BNY Mellon US Mid Cap Core Equity ETF          A
#
#   quality_score score_peer_rank score_global_rank carbon_intensity  \
# 0     6.71 / 10           59.87             71.96            47.00
# 1            --              --                --               --
# 2     5.86 / 10           36.69             38.51           136.16
# 3     7.67 / 10           91.67             67.35           110.60
# 4     6.45 / 10           50.28             89.07           201.79
#
#   sustainable_impact_exposure sri_screening_criteria_exposure
# 0                          --                           8.27%
# ...

# %%
df_etf_1_10 = pd.concat([df_etf_1, df_etf_2, df_etf_3, df_etf_4, df_etf_5, df_etf_6, df_etf_7, df_etf_8, df_etf_9, df_etf_10], axis = 0)

# %%
df_etf_1_10.shape
# Out:
# (1000, 9)

# %%
df_etf_1_10.head()
# Out:
#   ticker                        fund_name esg_rating quality_score  \
# 0    SPY           SPDR S&P 500 ETF Trust          A     6.68 / 10
# 1    IVV         iShares Core S&P 500 ETF          A     6.68 / 10
# 2    VOO          Vanguard 500 Index Fund          A     6.68 / 10
# 3    VTI  Vanguard Total Stock Market ETF          A     6.52 / 10
# 4    QQQ                Invesco QQQ Trust          A     6.71 / 10
#
#   score_peer_rank score_global_rank carbon_intensity  \
# 0           58.71             47.34           122.31
# 1           58.67             47.01           122.41
# 2           58.75             47.99           122.47
# 3           52.51             24.74           122.61
# 4           59.94             55.16            47.01
#
#   sustainable_impact_exposure sri_screening_criteria_exposure
# 0                          --                           9.75%
# 1                          --                           9.67%
# ...

# %%
df_etf_1_10.replace('--', 'NaN', inplace = True)
df_etf_1_10['carbon_intensity'].astype(str)
df_etf_1_10['carbon_intensity'] = df_etf_1_10['carbon_intensity'].str.replace(',', '')
df_etf_1_10.head(10)
# Out:
#   ticker                             fund_name esg_rating quality_score  \
# 0    SPY                SPDR S&P 500 ETF Trust          A     6.68 / 10
# 1    IVV              iShares Core S&P 500 ETF          A     6.68 / 10
# 2    VOO               Vanguard 500 Index Fund          A     6.68 / 10
# 3    VTI       Vanguard Total Stock Market ETF          A     6.52 / 10
# 4    QQQ                     Invesco QQQ Trust          A     6.71 / 10
# 5    VEA   Vanguard FTSE Developed Markets ETF         AA     7.41 / 10
# 6    VTV                    Vanguard Value ETF          A     6.50 / 10
# 7   IEFA            iShares Core MSCI EAFE ETF         AA     7.53 / 10
# 8    BND        Vanguard Total Bond Market ETF          A     6.08 / 10
# 9    AGG  iShares Core U.S. Aggregate Bond ETF          A     6.07 / 10
#
#   score_peer_rank score_global_rank carbon_intensity  \
# 0           58.71             47.34           122.31
# 1           58.67             47.01           122.41
# ...

# %%
#f['filename'] = df['filename'].str.rstrip('.txt')
df_etf_1_10['quality_score'] = df_etf_1_10['quality_score'].str.rstrip('/ 10')
df_etf_1_10['sri_screening_criteria_exposure_%'] = df_etf_1_10['sri_screening_criteria_exposure'].str.rstrip('%')
df_etf_1_10.drop('sri_screening_criteria_exposure', inplace = True, axis = 1)
df_etf_1_10.shape
# Out:
# (1000, 9)

# %%
df_etf_1_10['score_peer_rank'] = df_etf_1_10['score_peer_rank'].astype(float)
df_etf_1_10['score_global_rank'] = df_etf_1_10['score_global_rank'].astype(float)
df_etf_1_10['carbon_intensity'] = df_etf_1_10['carbon_intensity'].astype(float)
df_etf_1_10['sri_screening_criteria_exposure_%'] = df_etf_1_10['sri_screening_criteria_exposure_%'].astype(float)

# %%
df_etf_1_10['quality_score'] = df_etf_1_10['quality_score'].astype(float)

# %%
df_etf_1_10.set
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 df_etf_1_10.set
#
# File /usr/local/Caskroom/miniconda/base/envs/nf_cluster/lib/python3.9/site-packages/pandas/core/generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'set'
