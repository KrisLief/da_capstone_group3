# %%
import pandas as pd
import numpy as np
import psycopg2
from sql_functions import get_dataframe
from sql_functions import get_engine
engine = get_engine()

# %%
etfs_sql = 'SELECT * FROM public.etf_esg_merged_final_final'
etfs = get_dataframe(etfs_sql)

# %%
etfs['segment'].astype(str)
# Out:
# 0                      Equity: U.S.  -  Large Cap
# 1                      Equity: U.S.  -  Large Cap
# 2                      Equity: U.S.  -  Large Cap
# 3                   Equity: U.S.  -  Total Market
# 4                      Equity: U.S.  -  Large Cap
#                           ...
# 2178                      Equity: Global Consumer
# 2179    Asset Allocation: Global - Target Outcome
# 2180                Equity: U.S.  -  Total Market
# 2181              Equity: Russia  -  Total Market
# 2182                      Equity: Global Internet
# Name: segment, Length: 2183, dtype: object

# %%
etfs[['main_segment', 'sub_segment']] = etfs.segment.str.split(':', expand = True)
etfs.head()
# Out:
#   ticker                        fund_name                        segment  \
# 0    SPY           SPDR S&P 500 ETF Trust     Equity: U.S.  -  Large Cap
# 1    IVV         iShares Core S&P 500 ETF     Equity: U.S.  -  Large Cap
# 2    VOO          Vanguard 500 Index Fund     Equity: U.S.  -  Large Cap
# 3    VTI  Vanguard Total Stock Market ETF  Equity: U.S.  -  Total Market
# 4    QQQ                Invesco QQQ Trust     Equity: U.S.  -  Large Cap
#
#    one_yr_return  expense_ratio           aum  analyst_pick grade  efficiency  \
# 0          17.03           0.09  4.259800e+11          True     A        99.0
# 1          17.08           0.03  3.516200e+11          True     A       100.0
# 2          17.09           0.03  3.363100e+11          True     A        99.0
# 3          16.46           0.03  3.196800e+11          True     A        99.0
# 4          27.05           0.20  2.093000e+11          True     A        97.0
#
#    tradability  ...  p_as_of_date  esg_rating  quality_score_10  \
# 0        100.0  ...    2023-07-25           A              6.68
# 1        100.0  ...    2023-07-25           A              6.68
# 2        100.0  ...    2023-07-25           A              6.68
# 3        100.0  ...    2023-07-25           A              6.52
# 4        100.0  ...    2023-07-25           A              6.70
#
#    score_global_rank  sustainable_impact_exposure  \
# 0              58.71                          NaN
# 1              58.67                          NaN
# 2              58.75                          NaN
# 3              52.51                          NaN
# 4              59.94                          NaN
#
#    sri_screening_criteria_exposure_% score_peer_rank carbon_intensity  \
# 0                               9.75           58.71           122.31
# 1                               9.67           58.67           122.41
# 2                               9.76           58.75           122.47
# 3                               8.86           52.51           122.61
# 4                               8.36           59.94            47.01
#
#    main_segment             sub_segment
# 0        Equity      U.S.  -  Large Cap
# 1        Equity      U.S.  -  Large Cap
# 2        Equity      U.S.  -  Large Cap
# 3        Equity   U.S.  -  Total Market
# 4        Equity      U.S.  -  Large Cap
#
# [5 rows x 35 columns]

# %%
etfs.drop(["segment", "score_peer_rank", "sustainable_impact_exposure"], axis = 1, inplace = True)

# %%
etfs.head()
# Out:
#   ticker                        fund_name  one_yr_return  expense_ratio  \
# 0    SPY           SPDR S&P 500 ETF Trust          17.03           0.09
# 1    IVV         iShares Core S&P 500 ETF          17.08           0.03
# 2    VOO          Vanguard 500 Index Fund          17.09           0.03
# 3    VTI  Vanguard Total Stock Market ETF          16.46           0.03
# 4    QQQ                Invesco QQQ Trust          27.05           0.20
#
#             aum  analyst_pick grade  efficiency  tradability   fit  ...  \
# 0  4.259800e+11          True     A        99.0        100.0  96.0  ...
# 1  3.516200e+11          True     A       100.0        100.0  96.0  ...
# 2  3.363100e+11          True     A        99.0        100.0  96.0  ...
# 3  3.196800e+11          True     A        99.0        100.0  99.0  ...
# 4  2.093000e+11          True     A        97.0        100.0  67.0  ...
#
#    p_five_yr  p_ten_yr  p_as_of_date  esg_rating  quality_score_10  \
# 0      11.79     12.48    2023-07-25           A              6.68
# 1      11.82     12.54    2023-07-25           A              6.68
# 2      11.82     12.55    2023-07-25           A              6.68
# 3      10.98     11.98    2023-07-25           A              6.52
# 4      16.50     18.66    2023-07-25           A              6.70
#
#   score_global_rank sri_screening_criteria_exposure_%  carbon_intensity  \
# 0             58.71                              9.75            122.31
# 1             58.67                              9.67            122.41
# 2             58.75                              9.76            122.47
# 3             52.51                              8.86            122.61
# 4             59.94                              8.36             47.01
#
#    main_segment             sub_segment
# 0        Equity      U.S.  -  Large Cap
# 1        Equity      U.S.  -  Large Cap
# 2        Equity      U.S.  -  Large Cap
# 3        Equity   U.S.  -  Total Market
# 4        Equity      U.S.  -  Large Cap
#
# [5 rows x 32 columns]

# %%
table_name = 'etfs_segmented'

# %%
# Write records stored in a dataframe to SQL database
if engine!=None:
    try:
        etfs.to_sql(name=table_name, # Name of SQL table variable
                        con=engine, # Engine or connection
                        schema='public', # your class schema variable
                        if_exists='replace', # Drop the table before inserting new values 
                        index=False, # Write DataFrame index as a column
                        chunksize=5000, # Specify the number of rows in each batch to be written at a time
                        method='multi') # Pass multiple values in a single INSERT clause
        print(f"The {table_name} table was imported successfully.")
    # Error handling
    except (Exception, psycopg2.DatabaseError) as error:
        print(error)
        engine = None
else:
    print('No engine')
# Out:
# The etfs_segmented table was imported successfully.
