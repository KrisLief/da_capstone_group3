# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/Users/kk/Desktop/da_capstone_group3/Team3_App/df_merged_etf_fixed.csv')
df.columns
# Out:
# Index(['Unnamed: 0', 'ticker', 'one_yr_return', 'expense_ratio', 'aum',
#        'dividend_yield', 'fundname', 'esg_rating', 'quality_score',
#        'score_peer_rank', 'score_global_rank', 'carbon_intensity',
#        'sustainable_impact_exposure', 'sri_screening_criteria_exposure',
#        'analyst_pick', 'grade', 'efficiency', 'tradability', 'fit', 'segment',
#        'one_mo_p_percent', 'three_mo_p_percent', 'ytd_p_percent',
#        'one_yr_p_percent', 'three_yr_p_percent', 'five_yr_p_percent',
#        'ten_yr_p_percent', 'one_mo', 'three_mo', 'ytd', 'one_yr', 'three_yr',
#        'as_of_date'],
#       dtype='object')

# %%
performance = df[['one_mo_p_percent', 'three_mo_p_percent', 'ytd_p_percent',
       'one_yr_p_percent', 'three_yr_p_percent', 'five_yr_p_percent',
       'ten_yr_p_percent']]

# %%
performance
# Out:
#       one_mo_p_percent  three_mo_p_percent  ytd_p_percent  one_yr_p_percent  \
# 0                 5.13               12.57          20.00             17.03
# 1                 5.14               12.61          20.04             17.08
# 2                 5.15               12.62          20.09             17.09
# 3                 5.56               12.94          19.61             16.46
# 4                 4.48               22.36          42.66             27.05
# ...                ...                 ...            ...               ...
# 3163               NaN                 NaN            NaN               NaN
# 3164            -17.10              -58.45         -74.30               NaN
# 3165               NaN                 NaN            NaN               NaN
# 3166              4.45                7.88            NaN               NaN
# 3167              3.14                4.65            NaN               NaN
#
#       three_yr_p_percent  five_yr_p_percent  ten_yr_p_percent
# 0                  14.09              11.79             12.48
# 1                  14.15              11.82             12.54
# 2                  14.15              11.82             12.55
# 3                  13.42              10.98             11.98
# 4                  14.71              16.50             18.66
# ...                  ...                ...               ...
# 3163                 NaN                NaN               NaN
# 3164                 NaN                NaN               NaN
# 3165              -24.56             -13.17               NaN
# 3166                 NaN                NaN               NaN
# 3167                 NaN                NaN               NaN
#
# [3168 rows x 7 columns]

# %%
performance = pd.DataFrame(performance)
performance.rename(columns={'one_mo_p_percent': '1 mo', 'three_mo_p_percent': '3 mo', 'ytd_p_percent': '9 mo', 'one_yr_p_percent': '12 mo', 'three_yr_p_percent': '36 mo', 'five_yr_p_percent': '60 mo', 'ten_yr_p_percent': '120 mo'}, inplace=True)
performance.head()
# Out:
#    1 mo   3 mo   9 mo  12 mo  36 mo  60 mo  120 mo
# 0  5.13  12.57  20.00  17.03  14.09  11.79   12.48
# 1  5.14  12.61  20.04  17.08  14.15  11.82   12.54
# 2  5.15  12.62  20.09  17.09  14.15  11.82   12.55
# 3  5.56  12.94  19.61  16.46  13.42  10.98   11.98
# 4  4.48  22.36  42.66  27.05  14.71  16.50   18.66

# %%
performance= performance.drop('ticker', axis=1)
performance.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 performance= performance.drop('ticker', axis=1)
#       2 performance.head()
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/ml_env/lib/python3.11/site-packages/pandas/core/frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
#    5262         columns=columns,
#    5263         level=level,
#    5264         inplace=inplace,
#    5265         errors=errors,
#    5266     )
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/ml_env/lib/python3.11/site-packages/pandas/core/generic.py:4549, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4547 for axis, labels in axes.items():
#    4548     if labels is not None:
# -> 4549         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4551 if inplace:
#    4552     self._update_inplace(obj)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/ml_env/lib/python3.11/site-packages/pandas/core/generic.py:4591, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4589         new_axis = axis.drop(labels, level=level, errors=errors)
#    4590     else:
# -> 4591         new_axis = axis.drop(labels, errors=errors)
#    4592     indexer = axis.get_indexer(new_axis)
#    4594 # Case for non-unique axis
#    4595 else:
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/ml_env/lib/python3.11/site-packages/pandas/core/indexes/base.py:6699, in Index.drop(self, labels, errors)
#    6697 if mask.any():
#    6698     if errors != "ignore":
# -> 6699         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6700     indexer = indexer[~mask]
#    6701 return self.delete(indexer)
#
# KeyError: "['ticker'] not found in axis"

# %%
x = [1, 3, 9, 12, 36, 60, 120]

for i in performance:
    y= pd.DataFrame(performance[i].astype(float))

# %%
for ticker in performance.index:
    df_performance = dict({ticker[i] : (x, y)} for ticker in performance.columns)
    df_performance

# %%
for i in performance:
    performance.index = pd.DataFrame(df['ticker'])

# %%
df_performance = [[ {ticker : (x, y)}] for ticker in performance.columns]

# %%
df_performance = pd.DataFrame(df_performance.reset_index())

# %%
df_performance

# %%
sns.lineplot(data=performance.index[1], x=x, y=y)

# %%
performance = performance.set_index('ticker')
performance.head()

# %%
performance = performance.groupby('ticker')
performance.head()

# %%
perfomance.columns.values.tolist()

# %%
performance_df = pd.DataFrame()

for ticker, ticker_df in performance:
    x=['1 mo', '3 mo', '9 mo', '12 mo', '36 mo', '60 mo', '120 mo']
    i= perfomance.columns[ticker]
    y = i.values.tolist()


    sns.lineplot(data=ts, x=x, y=y, hue=index)

# %%
performance = performance.T

# %%
performance = pd.DataFrame(performance)


performance['month'] = ['1 mo', '3 mo', '9 mo', '12 mo', '36 mo', '60 mo', '120 mo']
performance = performance.set_index('month')
performance.head()

# %%
performance = performance.sortby('ticker')

# %%
sns.lineplot(data=performance.head(1), performance.ticker=['SPY'	,'IVV' , 'VOO',	'VTI',	'QQQ'] palette="tab10", linewidth=0.5)

# %%
performance.to_csv('performance.csv')

# %%
for i in range(3168):
    p[i] = df.ticker[i]
    print(p[i])

# %%
ts = pd.DataFrame(performance, index=df['ticker'])  # Replace index with your tickers
ts.Ticker = df[

# %%
df.ticker

# %%
ts = pd.DataFrame(performance.head(50), index=df['ticker'].head(50))  # Replace index with your tickers

# Plotting
plt.figure(figsize=(10, 30))

for ticker in ts.index:
    plt.plot(ts.columns, ts.loc[ticker])

plt.xlabel("Time")
plt.ylabel("Values")
plt.title("Time Series Comparison for Tickers")
plt.legend()
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()

plt.show()

# %%
performance = perfomance.rename(columns={'one_mo_p_percent':'1 Month', 'three_mo_p_percent':'3 Month', 'ytd_p_percent':'9 Month', 'one_yr_p_percent':'1 Year', 'three_yr_p_percent':'3 Year', 'five_yr_p_percent':'5 Year', 'ten_yr_p_percent':'10 Year'})
performance

# %%
month= [1,3,9,12,36,60,120]
def plots():
    for i in performance.ticker:
        plt.figure(figsize=(10,6))
        plt.title([i])
        plt.ylabel('performance [%]')
        plt.xlabel('time in months')
        sns.lineplot(x= month, y= performance.loc[i], )
        plt.show()

# %%
plots()

# %%
month = [1, 3, 9, 12, 36, 60, 120]
ts['SPY'] = pd.DataFrame(indexs=month, index=performance.loc['SPY'])

ts['SPY']

# %%
month

# %%
performance = performance.T
performance = performance.rename(columns={'ticker':'month'})
performance = pd.concat([performance, month], axis=0)
performance['month'] = month

# %%
performance.head(20)

# %%
#performance.index =['1', '3', '9', '12', '36', '60', '120']

#performance= performance.drop('level_0', axis=1)
performance= performance.drop('index', axis=1)
performance

# %%
performance

# %%
performance

# %%
sns.lineplot(data=perfomance, x='index', y='values')

# %% [markdown]
# -------

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import yfinance as yf
import yahooquery as yq
from yahooquery import Ticker
from yfinance import ticker
import googlefinance as gf
from googlefinance import getQuotes
import requests
import json
from json import dumps
from json import loads
import datetime as dt
from datetime import datetime
import streamlit as st

# %%
selection = pd.read_csv('/Users/kk/Desktop/da_capstone_group3/Team3_App/buraks_list49.csv')
selection.head()
# Out:
#    Unnamed: 0 start_config  one_yr_return  expense_ratio           aum  \
# 0          79    lightgray          21.31           0.11  1.933000e+10
# 1         159    lightgray          28.67           0.52  8.370000e+09
# 2         169    lightgray          21.73           0.09  7.660000e+09
# 3         259    lightgray          20.95           0.09  4.360000e+09
# 4         341    lightgray          15.10           0.50  2.860000e+09
#
#    dividend_yield  quality_score  score_peer_rank  score_global_rank  \
# 0            2.99           7.82            94.27              38.17
# 1            2.81           7.85            94.72              40.60
# 2            2.98           7.91            96.00              51.26
# 3            2.97           7.82            94.14              37.32
# 4            3.84           7.94            96.35              55.57
#
#    carbon_intensity  ...  investment_strategy  asset_region    subsegment  \
# 0             93.80  ...             standard        europe  total_market
# 1            123.75  ...             standard        europe  total_market
# 2            100.13  ...             standard        europe  total_market
# 3            101.02  ...             standard        europe  total_market
# 4             80.41  ...             standard        europe  total_market
#
#    ticker  three_mo_p_percent  dividend_yield_cat  carbon_intensity_cat  \
# 0     VGK                2.80                  q4                    q2
# 1     EZU                3.00                  q4                    q2
# 2    BBEU                2.41                  q4                    q2
# 3    IEUR                2.35                  q4                    q2
# 4     EWU                2.00                high                    q2
#
#    aum_cat  quality_score_cat  ranking
# 0     high               high      NaN
# 1     high               high      NaN
# 2     high               high      NaN
# 3     high               high      NaN
# 4     high               high      NaN
#
# [5 rows x 42 columns]

# %%
performance = selection[['one_mo_p_percent', 'three_mo_p_percent', 'ytd_p_percent', 'one_yr_p_percent', 'three_yr_p_percent', 'five_yr_p_percent', 'ten_yr_p_percent']]

for i in selection: 
    performance.T.rename(columns={i : 'ticker[i]'}, inplace=True)

# %%
p_selection = pd.DataFrame(performance.T)

p_selection = pd.concat([p_selection, selection['ticker']], axis=1)

p_selection
# Out:
#                         0      1      2      3      4      5      6      7  \
# one_mo_p_percent     5.02   4.76   4.68   4.99   4.53   4.21   4.64   3.80
# three_mo_p_percent   2.80   3.00   2.41   2.35   2.00   3.02   2.37   2.75
# ytd_p_percent       16.50  19.90  16.33  16.05  11.19  22.36  16.51  20.44
# one_yr_p_percent    21.31  28.67  21.73  20.95  15.10  35.36  21.91  29.49
# three_yr_p_percent   9.56   9.39   9.93   9.53  12.33  10.60   9.84   3.18
# five_yr_p_percent    5.00   4.42   5.23   4.87   2.84   5.95   5.13   1.16
# ten_yr_p_percent     5.34   5.42    NaN    NaN   2.84   5.61   5.02   3.35
# 0                     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1                     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2                     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 3                     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 4                     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 5                     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 6                     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 7                     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 8                     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 9                     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 10                    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 11                    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 12                    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 13                    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 14                    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 15                    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 16                    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 17                    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 18                    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 19                    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 20                    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 21                    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 22                    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 23                    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 24                    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 25                    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 26                    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 27                    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 28                    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 29                    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 30                    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 31                    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 32                    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 33                    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 34                    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 35                    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 36                    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 37                    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 38                    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 39                    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 40                    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 41                    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 42                    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 43                    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 44                    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 45                    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 46                    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 47                    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 48                    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
#                         8      9  ...    40     41     42    43     44     45  \
# one_mo_p_percent     8.48   4.11  ...  3.37   3.98   5.35  4.54   2.59   5.01
# three_mo_p_percent   7.88   2.87  ... -3.96   2.85   2.81  1.28   2.67   2.95
# ytd_p_percent       19.02  20.74  ... -2.44  21.07  17.31  9.70  18.09  12.42
# one_yr_p_percent    35.07  24.14  ...  4.31  30.42  22.46  6.94  23.85  10.39
# three_yr_p_percent  14.83  13.09  ...  1.18   3.66   9.04  6.19   7.21   6.44
# five_yr_p_percent    3.35   7.21  ...  0.68   1.94   4.93  0.12   4.94   2.37
# ten_yr_p_percent     2.99   8.71  ...  6.09    NaN    NaN   NaN   6.80    NaN
# 0                     NaN    NaN  ...   NaN    NaN    NaN   NaN    NaN    NaN
# 1                     NaN    NaN  ...   NaN    NaN    NaN   NaN    NaN    NaN
# 2                     NaN    NaN  ...   NaN    NaN    NaN   NaN    NaN    NaN
# 3                     NaN    NaN  ...   NaN    NaN    NaN   NaN    NaN    NaN
# 4                     NaN    NaN  ...   NaN    NaN    NaN   NaN    NaN    NaN
# 5                     NaN    NaN  ...   NaN    NaN    NaN   NaN    NaN    NaN
# 6                     NaN    NaN  ...   NaN    NaN    NaN   NaN    NaN    NaN
# 7                     NaN    NaN  ...   NaN    NaN    NaN   NaN    NaN    NaN
# 8                     NaN    NaN  ...   NaN    NaN    NaN   NaN    NaN    NaN
# 9                     NaN    NaN  ...   NaN    NaN    NaN   NaN    NaN    NaN
# 10                    NaN    NaN  ...   NaN    NaN    NaN   NaN    NaN    NaN
# 11                    NaN    NaN  ...   NaN    NaN    NaN   NaN    NaN    NaN
# 12                    NaN    NaN  ...   NaN    NaN    NaN   NaN    NaN    NaN
# 13                    NaN    NaN  ...   NaN    NaN    NaN   NaN    NaN    NaN
# 14                    NaN    NaN  ...   NaN    NaN    NaN   NaN    NaN    NaN
# 15                    NaN    NaN  ...   NaN    NaN    NaN   NaN    NaN    NaN
# 16                    NaN    NaN  ...   NaN    NaN    NaN   NaN    NaN    NaN
# 17                    NaN    NaN  ...   NaN    NaN    NaN   NaN    NaN    NaN
# 18                    NaN    NaN  ...   NaN    NaN    NaN   NaN    NaN    NaN
# 19                    NaN    NaN  ...   NaN    NaN    NaN   NaN    NaN    NaN
# 20                    NaN    NaN  ...   NaN    NaN    NaN   NaN    NaN    NaN
# 21                    NaN    NaN  ...   NaN    NaN    NaN   NaN    NaN    NaN
# 22                    NaN    NaN  ...   NaN    NaN    NaN   NaN    NaN    NaN
# 23                    NaN    NaN  ...   NaN    NaN    NaN   NaN    NaN    NaN
# 24                    NaN    NaN  ...   NaN    NaN    NaN   NaN    NaN    NaN
# 25                    NaN    NaN  ...   NaN    NaN    NaN   NaN    NaN    NaN
# 26                    NaN    NaN  ...   NaN    NaN    NaN   NaN    NaN    NaN
# 27                    NaN    NaN  ...   NaN    NaN    NaN   NaN    NaN    NaN
# 28                    NaN    NaN  ...   NaN    NaN    NaN   NaN    NaN    NaN
# 29                    NaN    NaN  ...   NaN    NaN    NaN   NaN    NaN    NaN
# 30                    NaN    NaN  ...   NaN    NaN    NaN   NaN    NaN    NaN
# 31                    NaN    NaN  ...   NaN    NaN    NaN   NaN    NaN    NaN
# 32                    NaN    NaN  ...   NaN    NaN    NaN   NaN    NaN    NaN
# 33                    NaN    NaN  ...   NaN    NaN    NaN   NaN    NaN    NaN
# 34                    NaN    NaN  ...   NaN    NaN    NaN   NaN    NaN    NaN
# 35                    NaN    NaN  ...   NaN    NaN    NaN   NaN    NaN    NaN
# 36                    NaN    NaN  ...   NaN    NaN    NaN   NaN    NaN    NaN
# 37                    NaN    NaN  ...   NaN    NaN    NaN   NaN    NaN    NaN
# 38                    NaN    NaN  ...   NaN    NaN    NaN   NaN    NaN    NaN
# 39                    NaN    NaN  ...   NaN    NaN    NaN   NaN    NaN    NaN
# 40                    NaN    NaN  ...   NaN    NaN    NaN   NaN    NaN    NaN
# 41                    NaN    NaN  ...   NaN    NaN    NaN   NaN    NaN    NaN
# 42                    NaN    NaN  ...   NaN    NaN    NaN   NaN    NaN    NaN
# 43                    NaN    NaN  ...   NaN    NaN    NaN   NaN    NaN    NaN
# 44                    NaN    NaN  ...   NaN    NaN    NaN   NaN    NaN    NaN
# 45                    NaN    NaN  ...   NaN    NaN    NaN   NaN    NaN    NaN
# 46                    NaN    NaN  ...   NaN    NaN    NaN   NaN    NaN    NaN
# 47                    NaN    NaN  ...   NaN    NaN    NaN   NaN    NaN    NaN
# 48                    NaN    NaN  ...   NaN    NaN    NaN   NaN    NaN    NaN
#
#                        46     47     48  ticker
# one_mo_p_percent     4.06   3.20   4.47     NaN
# three_mo_p_percent   0.29  -1.67   1.02     NaN
# ytd_p_percent       14.48   4.63  21.13     NaN
# one_yr_p_percent    13.57   9.50  29.84     NaN
# three_yr_p_percent   4.89  12.98  13.57     NaN
# five_yr_p_percent    3.57   4.63   6.82     NaN
# ten_yr_p_percent      NaN    NaN    NaN     NaN
# 0                     NaN    NaN    NaN     VGK
# 1                     NaN    NaN    NaN     EZU
# 2                     NaN    NaN    NaN    BBEU
# 3                     NaN    NaN    NaN    IEUR
# 4                     NaN    NaN    NaN     EWU
# 5                     NaN    NaN    NaN     FEZ
# 6                     NaN    NaN    NaN     IEV
# 7                     NaN    NaN    NaN     EWG
# 8                     NaN    NaN    NaN    EUFN
# 9                     NaN    NaN    NaN    HEDJ
# 10                    NaN    NaN    NaN     EWL
# 11                    NaN    NaN    NaN     EWQ
# 12                    NaN    NaN    NaN     EWP
# 13                    NaN    NaN    NaN    FLGB
# 14                    NaN    NaN    NaN    SPEU
# 15                    NaN    NaN    NaN    DBEU
# 16                    NaN    NaN    NaN    NUDM
# 17                    NaN    NaN    NaN    HEZU
# 18                    NaN    NaN    NaN     EWD
# 19                    NaN    NaN    NaN     EWN
# 20                    NaN    NaN    NaN     FEP
# 21                    NaN    NaN    NaN    EDEN
# 22                    NaN    NaN    NaN     FDD
# 23                    NaN    NaN    NaN     FSZ
# 24                    NaN    NaN    NaN    FLEE
# 25                    NaN    NaN    NaN    EIRL
# 26                    NaN    NaN    NaN    EUDG
# 27                    NaN    NaN    NaN     DAX
# 28                    NaN    NaN    NaN    EUSC
# 29                    NaN    NaN    NaN    NORW
# 30                    NaN    NaN    NaN     EWO
# 31                    NaN    NaN    NaN    FLSW
# 32                    NaN    NaN    NaN    EWUS
# 33                    NaN    NaN    NaN    PTEU
# 34                    NaN    NaN    NaN    DBEZ
# 35                    NaN    NaN    NaN    HEWG
# 36                    NaN    NaN    NaN    FLEH
# 37                    NaN    NaN    NaN    ENOR
# 38                    NaN    NaN    NaN     FKU
# 39                    NaN    NaN    NaN     EWK
# 40                    NaN    NaN    NaN    EFNL
# 41                    NaN    NaN    NaN    FLGR
# 42                    NaN    NaN    NaN    GSEU
# 43                    NaN    NaN    NaN    PGAL
# 44                    NaN    NaN    NaN    DBGR
# 45                    NaN    NaN    NaN    RFEU
# 46                    NaN    NaN    NaN    EUDV
# 47                    NaN    NaN    NaN    HEWU
# 48                    NaN    NaN    NaN    FLFR
#
# [56 rows x 50 columns]

# %%
fig, ax = plt.subplots((4),(2), figsize=(28, 32))
sns.set_theme(style="whitegrid")
fig.get_constrained_layout_pads()
log_aum = np.log(selection.aum)
selection['log_aum'] = log_aum

#convert aum to log for plot 
log_aum = np.log(selection.aum)
selection['log_aum'] = log_aum


ax1=ax[0,0]
ax2=ax[0,1]
ax3=ax[1,0]
ax4=ax[1,1]
ax5=ax[2,0]
ax6=ax[2,1]
ax7=ax[3,0]
ax8=ax[3,1]

ticker1 = selection.ticker.query("'ticker' != 'NUDM'")
ticker2 = selection.ticker.query("'ticker' == 'NUDM'")

sns.barplot(x="ticker1", y="dividend_yield", data=selection.sort_values(by='dividend_yield', ascending=False), color='deepskyblue', ax=ax1)
sns.barplot(x="ticker2", y="dividend_yield", data=selection.sort_values(by='dividend_yield', ascending=False), color='firebrick', ax=ax1)
ax1.set_title('Dividend Yield')
ax1.tick_params(labelrotation=60)

sns.barplot(x="ticker1", y="quality_score", data=selection.sort_values(by='quality_score', ascending=False), color='deepskyblue', ax=ax2)
sns.barplot(x="ticker2", y="quality_score", data=selection.sort_values(by='quality_score', ascending=False), color='firebrick', ax=ax2)
ax2.set_title('Quality Score')
ax2.tick_params(labelrotation=60)

sns.barplot(x="ticker1", y="score_peer_rank", data=selection.sort_values(by='score_peer_rank', ascending=False) ,ax=ax3, color='deepskyblue')
sns.barplot(x="ticker2", y="score_peer_rank", data=selection.sort_values(by='score_peer_rank', ascending=False) ,ax=ax3, color='firebrick')
ax3.set_title('score_peer_rank')
ax3.tick_params(labelrotation=60)

sns.barplot(x="ticker1", y="score_global_rank", data=selection.sort_values(by='score_global_rank', ascending=False),color='deepskyblue', ax=ax4)
sns.barplot(x="ticker2", y="score_peer_rank", data=selection.sort_values(by='score_global_rank', ascending=False) ,ax=ax3, color='firebrick')
ax4.set_title('score_global_rank')
ax4.tick_params(labelrotation=60)

sns.barplot(x="ticker1", y="carbon_intensity", data=selection.sort_values(by='carbon_intensity', ascending=False),color='deepskyblue', ax=ax5)
sns.barplot(x="ticker2", y="carbon_intensity", data=selection.sort_values(by='carbon_intensity', ascending=False),color='firebrick', ax=ax5)
ax5.set_title('carbon_intensity')
ax5.tick_params(labelrotation=60)

sns.barplot(x="ticker1", y="expense_ratio", data=selection.sort_values(by='expense_ratio', ascending=False), color='deepskyblue',ax=ax6)
sns.barplot(x="ticker2", y="expense_ratio", data=selection.sort_values(by='expense_ratio', ascending=False), color='firebrick',ax=ax6)
ax6.set_title('carbon_intensity')
ax6.tick_params(labelrotation=60)

sns.barplot(x="ticker1", y= "log_aum", data=selection.sort_values(by = "log_aum", ascending=False), color='deepskyblue',ax=ax7)
sns.barplot(x="ticker2", y= "log_aum", data=selection.sort_values(by = "log_aum", ascending=False), color='firebrick',ax=ax7)
ax7.set_title("log_aum")
ax7.tick_params(labelrotation=60)

sns.barplot(x="ticker1", y='sri_screening_criteria_exposure', data=selection.sort_values(by='sri_screening_criteria_exposure', ascending=False), color='deepskyblue',ax=ax8)
sns.barplot(x="ticker2", y='sri_screening_criteria_exposure', data=selection.sort_values(by='sri_screening_criteria_exposure', ascending=False), color='firebrick',ax=ax8)
ax8.set_title('sri_screening_criteria_exposure')
ax8.tick_params(labelrotation=60)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/b7/z37t9wv944zbx0thnr6_q22c0000gn/T/ipykernel_39412/3768974841.py in ?()
#      17 ax6=ax[2,1]
#      18 ax7=ax[3,0]
#      19 ax8=ax[3,1]
#      20
# ---> 21 ticker1 = selection.ticker.query("'ticker' != 'NUDM'")
#      22 ticker2 = selection.ticker.query("'ticker' == 'NUDM'")
#      23
#      24 sns.barplot(x="ticker1", y="dividend_yield", data=selection.sort_values(by='dividend_yield', ascending=False), color='deepskyblue', ax=ax1)
#
# /opt/homebrew/Caskroom/miniconda/base/envs/ml_env/lib/python3.11/site-packages/pandas/core/generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'query'

# %%
best = selection.query("esg_rating == 'AAA'").sort_values(by='dividend_yield', ascending=False)
best

# %% [markdown]
# ---------

# %%
nudm = yf.Ticker('NUDM')

# %%
yf.Ticker('NUDM').info
import yfinance as yf
from yfinance import ticker
from yfinance import reccomendations
from yfinance import options
from yfinance import ticker
from yfinance import utils
from yfinance import shared
from yfinance import multi
from yfinance import base
from yfinance import scraping
from yfinance import tickers
from yfinance import download
from yfinance import parsers
from yfinance import base
from yfinance import tickers


reccos=nudm.get_recommendations()
calendar=nudm.get_calendar()
divid=nudm.get_dividends()
earnings=nudm.get_earnings()
fins=nudm.get_financials()
info=nudm.get_info()
iholders=nudm.get_institutional_holders()
places=nudm.get_isin()
majorholds=nudm.get_major_holders()
mutholds=nudm.get_mutualfund_holders()
splits=nudm.get_splits()
sus=nudm.get_sustainability()
actions=nudm.get_actions()
bsheets=nudm.get_balance_sheet()
cflow=nudm.get_cashflow()

# %%
NUDM =nudm.info

# %%
hist.index

# %%
hist = nudm.history(period='max')
hist

# %%
hist = pd.DataFrame(hist, index=hist.index)
hist.describe()

# %%
fig, (ax) = plt.subplots(2,figsize=(20, 20))


ax1.set_xlabel('Date')
ax2.set_ylabel('Close')
ax1.set_xlabel('Date')
ax2.set_ylabel('Volume')
sns.lineplot(data=hist, x=hist.index, y='Close', color='royalblue', ax=ax[0])
sns.lineplot(data=hist, x=hist.index, y='Open', color='firebrick', ax=ax[0])
sns.lineplot(data=hist, x=hist.index, y='High', color='deepskyblue', ax=ax[0])
sns.lineplot(data=hist, x=hist.index, y='Low', color='deeppink', ax=ax[0])
sns.lineplot(data=hist, x=hist.index, y='Volume', color='forestgreen', ax=ax[1])

# %%
importnumpy as np
(hist['date'])
hist

# %%
selection.ticker

# %%
#get tickers from selection

t_list = selection.ticker
for t in t_list:
    t= selection.ticker.str.lower() 
    print(t)

# %%
from requests import get


for t in t_list:
    T =yq.Ticker('f"{selection.ticker[t]}"')
    print(T)

ts = pd.concat[T, selection.ticker]
print(get.json(object at 0x2d585d990))

# %%
s =yq.Ticker('f"{selection.ticker[t]}"')

for t in t_list:
    ts = s.history(period='max')
    print(s)

# %%
print(select_ts)

# %%
s#elect_ts = pd.DataFrame()
for t in t_list:
    ts = s.history(period='max')
    ts = select_ts
ts = print(ts).to_csv('select_ts.csv')

# %%
print(select_ts)

# %%
import requests
from requests import get
import json
from json import dumps
from json import loads

ts = get(select_ts)

# %%
select_ts = pd.DataFrame(select_ts)

select_ts.to_csv('/Users/kk/Desktop/da_capstone_group3/Team3_App/select_ts.csv')

# %%
ts['date']

# %%
ts.info()

ts['date'] = pd.to_datetime(ts.date)

# %%
for t in t_list:
    T_list = []
    T = yq.Ticker('f"{selection.ticker[t]}"')
    (f'{T}.info') = info[t]
    
    print(info[t])

# %%
for st in t_list:
    ts = pd.to_datetime(ts).reset_index(inplace=True)
    print(ts)

# %%
for t in t_list:
    ts['date'] = pd.to_datetime(ts['date'])
    print(ts)

# %%
import yahooquery as yq 
from yahooquery import Ticker 
from yahooquery import Screener
from yfinance import ticker
import googlefinance as gf
from googlefinance import getQuotes
import from json import normalize

t_list = selection.ticker
for t in t_list:
    t= selection.ticker.str.lower() 

t = yf.Ticker('f"{selection.ticker}"')

for t in t_list:
    
    t = yf.Ticker('f"{selection.ticker}"')
    print(f'"{t}"'.info)

# %%
# List of ticker symbols
ticker_symbols = ('f"{selection.ticker}"') # Add more tickers as needed

# Initialize an empty DataFrame to store combined holdings
combined_holdings = pd.DataFrame()

for ticker in ticker_symbols:
    # Fetch fund holding info for the current ticker
    fund = yf.Ticker("f'{ticker_symbols[t]}'"}'")
    fund_holdings = fund.fund_holding_info
    
    # Create DataFrame for current fund's holdings
    if ticker.lower() in fund_holdings:
        df = pd.DataFrame(fund_holdings[ticker.lower()]['holdings'])
        
        # Add a column for the current ticker symbol
        df['Ticker'] = ticker
        
        # Append the current fund's holdings to the combined DataFrame
        combined_holdings = combined_holdings.append(df, ignore_index=True)

# Print the combined holdings DataFrame
print(combined_holdings.head())

# %%
t_list = selection.ticker
for t in t_list:
    t= selection.ticker.str.lower() 


for t in t_list:
    yf_list = []
    yf_tic = yf.Ticker(f'selection.ticker["{t}"]')
    yf_list.append(yf_tic)
    print(yf_list)

# %%
fund = yq.Ticker('f"{t}"')
fund.fund_holding_info.keys()
#dict_keys(['hasgx'])

for t in selection.ticker:
    fund = yq.Ticker('f"{selection.ticker[t]}"')
    print(fund.fund_holding_info.keys())
from yahooquery import Ticker
from yfinance import ticker        
from yahooquery import Screener
import yahooquery as yq
import yahooquery
from yahooquery import get fetch                    

df_fund = pd.DataFrame(fund.get_holdings['ewu']['holdings'])

ewu = pd.DataFrame(fund_holding_info['ewu']['holdings'])

print(ewu)

# %%
nudm=yq.Ticker('NUDM')
nudm.get_trend_details
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[41], line 2
#       1 nudm=yq.Ticker('NUDM')
# ----> 2 nudm.get_trend_details
#
# AttributeError: 'Ticker' object has no attribute 'get_trend_details'

# %%
import yfinance as yf
nudm=yf.Ticker("NUDM")
fetch(nudm.info)

('NUDM')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[40], line 3
#       1 import yfinance as yf
#       2 nudm=yf.Ticker("NUDM")
# ----> 3 fetch(nudm.info)
#       5 ('NUDM')
#
# NameError: name 'fetch' is not defined

# %%
from yahooquery import fund
ticker('VGK') =  vgk.fund.get_['VGK']['holdings']

print(nudm)
# Out:
#   Cell In[21], line 2
#     ticker('VGK') =  vgk.fund.get_['VGK']['holdings']
#     ^
# SyntaxError: cannot assign to function call here. Maybe you meant '==' instead of '='?

# %%
nudm=yf.Ticker('NUDM')
print(nudm.get_trend_details)
# Out:
# <bound method TickerBase.get_trend_details of yfinance.Ticker object <NUDM>>

# %%
print(nudm.fund_holding_info.keys('yf_list'))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 print(nudm.fund_holding_info.keys('yf_list'))
#
# AttributeError: 'Ticker' object has no attribute 'fund_holding_info'

# %%
t_list = selection.ticker
for t in t_list:
    t= selection.ticker.str.lower() 
    print(t)

# %%
for t in t_list:
    
    t = yf.Ticker('f"{selection.ticker}"')
    print(f'"{t}"'.info)

# %%
t_list = selection.ticker
for t in t_list:
    t= selection.ticker.str.lower() 
    print(t)

# %%
print(ewu_HOLD)
fig, ax = plt.subplots(figsize=(10, 6))
ax.set_title('EWU Holdings')
ax.tick_params(labelrotation=60)
sns.barplot(x='holdingName', y= 'holdingPercent', data=ewu_HOLD.sort_values(by='holdingPercent', ascending=False), color='deepskyblue')

# %% [markdown]
# ---------

# %%
import pandas as pd
import yahooquery as yq
from yahooquery import Ticker
from yfinance import ticker
import yahooquery.misc 
import yahooquery.screener
import yahooquery.utils
import yahooquery.research

import yq_Ticker_object
import yfinance as yf
import time

# %%
# Create a Ticker object for the ticker symbol 'SPY'
ticker_obj = yq.ticker.Ticker('NUDM')

# Get the fund holding information in JSON format
nudm_info_json = ticker_obj.fund_holding_info

# Convert the JSON dictionary to a pandas DataFrame
fund_info_df = pd.DataFrame(fund_info_json['NUDM']['holdings'])

# Print the DataFrame
#print(fund_info_df)
fund_info_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[39], line 8
#       5 nudm_info_json = ticker_obj.fund_holding_info
#       7 # Convert the JSON dictionary to a pandas DataFrame
# ----> 8 fund_info_df = pd.DataFrame(fund_info_json['NUDM']['holdings'])
#      10 # Print the DataFrame
#      11 #print(fund_info_df)
#      12 fund_info_df
#
# NameError: name 'fund_info_json' is not defined

# %%
import pandas as pd
for t in t_list:
    yq_list = [] 
    t = yq.Ticker('f"{selection.ticker[t]}"')
    ticker_obj = fund
    nudm.fund_get_holdings(T)
    yq_list.append(ticker_obj)
    pd.to_Dataframe(yq_list)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 2
#       1 import pandas as pd
# ----> 2 for t in t_list:
#       3     yq_list = []
#       4     t = yq.Ticker('f"{selection.ticker[t]}"')
#
# NameError: name 't_list' is not defined

# %%
t_list = selection.ticker
for t in t_list:
    T= selection.ticker
    print(f"'{T}'")

# %%
t_list = selection.ticker
for t in t_list:
    t= selection.ticker.str.lower() 
    print(t)

# %%
ticker_obj[t] = yq.ticker.Ticker(T)
for t in t_list: 
    ticker_obj['f"{t}"'] = yq.ticker.Ticker('f"{T}"')
    T_objects = []
    T_objects.append(ticker_obj)
    print(T_objects)

# %%
ticker_obj = yq.ticker.Ticker('NUDM')

# %%
fund_info_json = ticker_obj.fund_holding_info

# %%
fund_info_df = pd.DataFrame(fund_info_json['NUDM']['holdings'])

# %%
fund_info_df

# %%
fund_info_df.holdingPercent.sum()

# %%
nudm.asset_profile['NUDM']['holdings']

# %%
fund_info_df = pd.DataFrame(fund_info_json['NUDM']['asset'])

# %%
fund = Ticker('NUDM')
weights = fund.fund_sector_weightings

# %%
print(weights)
# Out:
#                           NUDM
# 0
# realestate              0.0323
# consumer_cyclical       0.1059
# basic_materials         0.0734
# consumer_defensive      0.1095
# technology              0.1056
# communication_services  0.0566
# financial_services      0.1881
# utilities               0.0257
# industrials             0.1624
# energy                  0.0170
# healthcare              0.1236

# %%
weights.sum()
# Out:
# NUDM    1.0001
# dtype: float64

# %%
nudm = yq.Ticker('NUDM')
yq.find_all_modules(nudm)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[31], line 2
#       1 nudm = yq.Ticker('NUDM')
# ----> 2 yq.find_all_modules(nudm)
#
# AttributeError: module 'yahooquery' has no attribute 'find_all_modules'

# %%
pd.read_json(nudm.all_financial_data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 pd.read_json(nudm.all_financial_data)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/ml_env/lib/python3.11/site-packages/pandas/io/json/_json.py:760, in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options, dtype_backend, engine)
#     757 if convert_axes is None and orient != "table":
#     758     convert_axes = True
# --> 760 json_reader = JsonReader(
#     761     path_or_buf,
#     762     orient=orient,
#     763     typ=typ,
#     764     dtype=dtype,
#     765     convert_axes=convert_axes,
#     766     convert_dates=convert_dates,
#     767     keep_default_dates=keep_default_dates,
#     768     precise_float=precise_float,
#     769     date_unit=date_unit,
#     770     encoding=encoding,
#     771     lines=lines,
#     772     chunksize=chunksize,
#     773     compression=compression,
#     774     nrows=nrows,
#     775     storage_options=storage_options,
#     776     encoding_errors=encoding_errors,
#     777     dtype_backend=dtype_backend,
#     778     engine=engine,
#     779 )
#     781 if chunksize:
#     782     return json_reader
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/ml_env/lib/python3.11/site-packages/pandas/io/json/_json.py:861, in JsonReader.__init__(self, filepath_or_buffer, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, lines, chunksize, compression, nrows, storage_options, encoding_errors, dtype_backend, engine)
#     859     self.data = filepath_or_buffer
#     860 elif self.engine == "ujson":
# --> 861     data = self._get_data_from_filepath(filepath_or_buffer)
#     862     self.data = self._preprocess_data(data)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/ml_env/lib/python3.11/site-packages/pandas/io/json/_json.py:901, in JsonReader._get_data_from_filepath(self, filepath_or_buffer)
#     894 filepath_or_buffer = stringify_path(filepath_or_buffer)
#     895 if (
#     896     not isinstance(filepath_or_buffer, str)
#     897     or is_url(filepath_or_buffer)
#     898     or is_fsspec_url(filepath_or_buffer)
#     899     or file_exists(filepath_or_buffer)
#     900 ):
# --> 901     self.handles = get_handle(
#     902         filepath_or_buffer,
#     903         "r",
#     904         encoding=self.encoding,
#     905         compression=self.compression,
#     906         storage_options=self.storage_options,
#     907         errors=self.encoding_errors,
#     908     )
#     909     filepath_or_buffer = self.handles.handle
#     910 elif (
#     911     isinstance(filepath_or_buffer, str)
#     912     and filepath_or_buffer.lower().endswith(
#    (...)
#     915     and not file_exists(filepath_or_buffer)
#     916 ):
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/ml_env/lib/python3.11/site-packages/pandas/io/common.py:716, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     713     codecs.lookup_error(errors)
#     715 # open URLs
# --> 716 ioargs = _get_filepath_or_buffer(
#     717     path_or_buf,
#     718     encoding=encoding,
#     719     compression=compression,
#     720     mode=mode,
#     721     storage_options=storage_options,
#     722 )
#     724 handle = ioargs.filepath_or_buffer
#     725 handles: list[BaseBuffer]
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/ml_env/lib/python3.11/site-packages/pandas/io/common.py:456, in _get_filepath_or_buffer(filepath_or_buffer, encoding, compression, mode, storage_options)
#     452 if not (
#     453     hasattr(filepath_or_buffer, "read") or hasattr(filepath_or_buffer, "write")
#     454 ):
#     455     msg = f"Invalid file path or buffer object type: {type(filepath_or_buffer)}"
# --> 456     raise ValueError(msg)
#     458 return IOArgs(
#     459     filepath_or_buffer=filepath_or_buffer,
#     460     encoding=encoding,
#    (...)
#     463     mode=mode,
#     464 )
#
# ValueError: Invalid file path or buffer object type: <class 'method'>

# %%
from git import FetchInfo


FetchInfo(get.json.0x286d41c90)

# %%
data["ds"] = pd.to_datetime(data["ds"], format="%Y-%m-%d")

pd.to_Series(data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 data["ds"] = pd.to_datetime(data["ds"], format="%Y-%m-%d")
#       3 pd.to_Series(data)
#
# NameError: name 'data' is not defined

# %%
data.columns = data[ds, y]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 data.columns = data[ds, y]
#
# NameError: name 'data' is not defined

# %%
data =data.set_index('ds')
print(data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 data =data.set_index('ds')
#       2 print(data)
#
# NameError: name 'data' is not defined

# %%
data.ds = pd.to_datetime(data.ds)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 data.ds = pd.to_datetime(data.ds)
#
# NameError: name 'data' is not defined

# %%
nmdm.
# Out:
#   Cell In[37], line 1
#     nmdm.
#          ^
# SyntaxError: invalid syntax

# %%
import prophet
from prophet import Prophet

data =data.set_index('ds')

# %%
data = data.rename(columns={'ds':'ds', 'y':'y'})

# %%
data= pd.to_datetime(data.index)

# %%
data

# %%
nudm.data=('ds', y, daily_seasonality=True)
prophet = Prophet(daily_seasonality=True) 
prophet.fit(data)

# %% [markdown]
# __________

# %%
prophet = Prophet(daily_seasonality=True)
prophet.fit(data)

# %% [markdown]
# prophet
# xgboost
# (s)amira
# lin_reg
# log_reg
# mcmc

# %%
hist

# %%
data = hist['Close']
data

# %%
data = data.reset_index()

# %%
data.index
data= data.rename(columns= {'Date':'ds', 'Close':'y'}, inplace=True).set_index('ds')
data.head()

# %%
print(data)

# %%
prophet = Prophet(daily_seasonality=True)
prophet.fit(data)

# %%
from prophet import Prophet()
